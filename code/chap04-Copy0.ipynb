# %%
import thinkdsp
import thinkplot
import math
import numpy
from __future__ import print_function, division

# %%
duration = 0.5
framerate = 11025
n = framerate * duration
ys = numpy.random.uniform(-1, 1, n)
wave = thinkdsp.Wave(ys, framerate)
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave.plot()

# %%
spectrum = wave.make_spectrum()
spectrum.plot()

# %%
spectrum.plot_power()

# %%
integ = spectrum.make_integrated_spectrum()
integ.plot_power()
thinkplot.config(xlabel='frequency (Hz)',
                ylabel='cumulative power')
# Out:
# /home/maire/anaconda/lib/python2.7/site-packages/matplotlib/axes.py:4747: UserWarning: No labeled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labeled objects found. "

# %%
signal = thinkdsp.BrownianNoise()
wave = signal.make_wave(duration=0.5, framerate=11025)
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave.plot()

# %%
spectrum = wave.make_spectrum()
spectrum.plot_power(low=1, linewidth=1, alpha=0.5)
thinkplot.config(xlabel='frequency (Hz)',
                ylabel='power density')

# %%
spectrum = wave.make_spectrum()
spectrum.plot_power(low=1, linewidth=1, alpha=0.5)
thinkplot.config(xlabel='frequency (Hz)',
                ylabel='power density',
                xscale='log',
                yscale='log')

# %%
signal = thinkdsp.BrownianNoise()
wave = signal.make_wave(duration=0.5, framerate=11025)
spectrum = wave.make_spectrum()
spectrum.estimate_slope()
# Out:
# (-2.0213025123598327,
#  15.96747369199664,
#  -0.88830137473994908,
#  0.0,
#  0.019913545113594104)

# %%
signal = thinkdsp.PinkNoise(beta=0)
wave = signal.make_wave(duration=0.5)
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
signal = thinkdsp.PinkNoise(beta=1)
wave = signal.make_wave(duration=0.5)
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
signal = thinkdsp.PinkNoise(beta=2)
wave = signal.make_wave(duration=0.5)
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
for beta in [0, 1, 2]:
    signal = thinkdsp.PinkNoise(beta=beta)
    wave = signal.make_wave(duration=0.5)
    spectrum = wave.make_spectrum()
    spectrum.plot_power()
    
thinkplot.config(xlabel='frequency (Hz)',
                ylabel='power density',
                xscale='log',
                yscale='log')

# %%
PI2 = 2 * math.pi
framerate = 10000
amps = numpy.ones(5000)
offsets = numpy.random.uniform(0, PI2, 5000)
i = complex(0, 1)
hs = amps * numpy.exp(i * offsets)
spectrum = thinkdsp.Spectrum(hs, framerate=framerate)
spectrum.plot()

# %%
wave = spectrum.make_wave()
wave.normalize()
wave.make_audio()

# %%
import scipy
ts = numpy.linspace(0, 1, len(wave.ys))
ys = scipy.integrate.cumtrapz(wave.ys, ts)
wave2 = thinkdsp.Wave(ys, framerate)

# %%
wave2.normalize()
wave2.make_audio()

# %%
spectrum2 = wave2.make_spectrum()
spectrum2.plot_power(low=1, linewidth=1, alpha=0.5)
thinkplot.config(xscale='log', yscale='log')

# %%
spectrum2.estimate_slope()

# %%
sound=thinkdsp.read_wave('187855__oceanictrancer__dance-drum-hat-loop-130bpm.wav')
sound.make_audio()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-4-b3bed497ecc0> in <module>()
# ----> 1 sound=thinkdsp.read_wave('187855__oceanictrancer__dance-drum-hat-loop-130bpm.wav')
#       2 sound.make_audio()
#
# /home/maire/ThinkDSP/code/thinkdsp.pyc in read_wave(filename)
#      93     returns: Wave
#      94     """
# ---> 95     fp = open_wave(filename, 'r')
#      96
#      97     nchannels = fp.getnchannels()
#
# /home/maire/anaconda/lib/python2.7/wave.pyc in open(f, mode)
#     507             mode = 'rb'
#     508     if mode in ('r', 'rb'):
# --> 509         return Wave_read(f)
#     510     elif mode in ('w', 'wb'):
#     511         return Wave_write(f)
#
# /home/maire/anaconda/lib/python2.7/wave.pyc in __init__(self, f)
#     162         # else, assume it is an open file object already
#     163         try:
# --> 164             self.initfp(f)
#     165         except:
#     166             if self._i_opened_the_file:
#
# /home/maire/anaconda/lib/python2.7/wave.pyc in initfp(self, file)
#     142             chunkname = chunk.getname()
#     143             if chunkname == 'fmt ':
# --> 144                 self._read_fmt_chunk(chunk)
#     145                 self._fmt_chunk_read = 1
#     146             elif chunkname == 'data':
#
# /home/maire/anaconda/lib/python2.7/wave.pyc in _read_fmt_chunk(self, chunk)
#     271             self._sampwidth = (sampwidth + 7) // 8
#     272         else:
# --> 273             raise Error, 'unknown format: %r' % (wFormatTag,)
#     274         self._framesize = self._nchannels * self._sampwidth
#     275         self._comptype = 'NONE'
#
# Error: unknown format: 3

# %%
segment=sound.segment(start=1.0, duration=1)
segment.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spectrum=segment.make_spectrum()
spectrum.plot()

# %%
spectrum.low_pass(15000)
spectrum.plot()

# %%
spectrum.make_wave().make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spectrum.low_pass(2000)
spectrum.plot()
#.make_wave().make_audio()

# %%
spectrum.make_wave().make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
gram=segment.make_spectrogram(seg_length=1024)
gram.plot(high=100)

# %%
for t in gram.times():
    spectrum=gram.spec_map[t]
    spectrum.plot(color='blue', linewidth='0.5', alpha=0.1)

# %%
for t in gram.times():
    spectrum=gram.spec_map[t]
    spectrum.power
